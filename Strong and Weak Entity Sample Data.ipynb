# %% [markdown]
# # Sample Data Generation

# %% [markdown]
# ## Strong Entities

# %%
from faker import Faker
import random

fake = Faker()

# Generate sample data for TravEasy table (strong entities)
num_customers = 50

with open('sample_data_strong_entity.sql', 'w') as f:
    for _ in range(num_customers):
        TravEasy_strong_entities = {
            'customerId': fake.uuid4(),
            'street': fake.street_address(),
            'city': fake.city(),
            'state': fake.state_abbr(),
            'zipcode': fake.zipcode(),
            'email': fake.email(),
            'name': fake.name(),
            'restaurantId': fake.uuid4(),
            'restaurant_name': fake.company(),
            'restaurant_location': fake.address(),
            'restaurant_price': random.choice(['high', 'medium', 'low']),
            'navigationId': fake.uuid4(),
            'navigation_distance': fake.random_number(digits=2),
            'navigation_fare': fake.random_number(digits=2),
            'estimated_time': fake.time(),
            'transportation_method': fake.word(),
            'routing': random.choice(['Start from your home and head towards the nearest park', 'From the park, take a left turn and walk straight until you reach the library', 
                                    'Exit the library and turn right, continue walking until you see a coffee shop on your left', 'Take a break at the coffee shop, then continue straight until you reach the town square', 
                                    'Explore the town square and its surroundings', 'Afterward, head back home via a different route', 'Enjoy the journey!', 'Walk along the riverbank until you reach the bridge', 
                                    'Cross the bridge and turn right onto Main Street', 'Continue straight until you reach the market square', 'Visit the museum on the corner of Market and Elm Street', 'Take a detour through the old alleyways', 
                                    'Discover the hidden garden behind the old church', 'Pause for a moment of reflection at the church', 'Continue walking until you find the famous fountain']),
            'hotelId': fake.uuid4(),
            'amentities': random.choice(['Free Wi-Fi, Complimentary Breakfast, Fitness Center', 'Outdoor Pool, On-site Restaurant, 24-Hour Room Service', 'Business Center, Spa and Wellness Facilities, Concierge Service', 'Pet-Friendly Accommodations, Meeting and Event Spaces, Airport Shuttle Service',
                                       'Bar and Lounge Area, Valet Parking, Bicycle Rental Service', 'Game Room, Laundry Service, Gift Shop', 'Children Play Area, Picnic Area, BBQ Facilities', 'Luggage Storage, Express Check-In/Check-Out, Currency Exchange', 'Library, Fireplace Lounge, Movie Screening Room', 
                                       'Tennis Court, Golf Course Access, Jogging Trails']),
            'hotel_street': fake.street_address(),
            'hotel_city': fake.city(),
            'hotel_state': fake.state_abbr(),
            'hotel_zipcode': fake.zipcode(),
            'duration_of_stay': fake.random_number(digits=2),
            'hotel_rating': random.randint(1, 5),
            'room_type_Id': fake.uuid4(),
            'room_type_name': random.choice(['Cozy Retreat Room', 'Executive King Suite', 'Deluxe Ocean View Room', 'Family Friendly Suite', 'Urban Loft Studio', 'Mountain Chalet Bedroom', 'Garden View Bungalow', 'Vintage Victorian Suite', 
                                           'Luxury Spa Room', 'Riverside Cabin Suite']),
            'max_guest': fake.random_number(digits=2),
            'total_rooms': fake.random_number(digits=3),
            'room_type_description': random.choice(['Cozy Single Bedroom', 'Spacious Master Suite', 'Modern Studio Apartment', 'Rustic Cabin Retreat', 'Luxurious Penthouse Loft', 'Charming Cottage Room', 'Elegant Executive Suite',
                                           'Quaint Guesthouse Bedroom', 'Contemporary Urban Loft', 'Seaside Villa Bedroom', 'Classic Victorian Chamber', 'Sleek City View Studio', 'Traditional Country Inn Room', 'Tropical Bungalow Bedroom',
                                           'Artistic Loft Space']),
            'room_price': fake.random_number(digits=4),
            'ticketID': fake.uuid4(),
            'flight_class': random.choice(['First Class', 'Business Class', 'Premium Economy', 'Economy Plus', 'Main Cabin Extra', 'Basic Economy', 'Premium Business', 'Economy Class', 'Comfort Class', 'Economy Flex']),
            'customerName': fake.name(),
            'flight_cost': fake.random_number(digits=4),
            'paymentId': fake.uuid4(),
            'payment_amount': fake.random_number(digits=4),
            'payment_type': random.choice(['Credit Card', 'Debit Card', 'Cash', 'Mobile Payment', 'Bank Transfer']),
            'transaction_assure': random.choice([1, 0]),
            'theft_prevention': random.choice([1, 0]),
            'flight_number': fake.random_number(digits=5),
            'flight_total_seats': fake.random_number(digits=2),
            'flight_duration': fake.random_number(digits=2),
            'flight_departure_location': fake.city(),
            'flight_arrival_time': fake.date_time(),
            'flight_arrival_location': fake.city(),
            'flight_departure_time': fake.date_time(),
            'airline_name': fake.company(),
            'airline_contact_information': fake.phone_number(),
            'flight_class_id': fake.uuid4(),
            'flight_class_fare': fake.random_number(digits=3),
            'flight_class_type': random.choice(['First Class', 'Business Class', 'Premium Economy', 'Economy Plus', 'Main Cabin Extra', 'Basic Economy', 'Premium Business', 'Economy Class', 'Comfort Class', 'Economy Flex'])
        }
        
        f.write("INSERT INTO TravEasy_strong_entities (customerId, street, city, state, zipcode, email, name, restaurantId, restaurant_name, restaurant_location, restaurant_price, navigationId, navigation_distance, navigation_fare, estimated_time, transportation_method, routing, hotelId, amentities, hotel_street, hotel_city, hotel_state, hotel_zipcode, duration_of_stay, hotel_rating, room_type_Id, room_type_name, max_guest, total_rooms, room_type_description, room_price, ticketID, flight_class, customerName, flight_cost, paymentId, payment_amount, payment_type, transaction_assure, theft_prevention, flight_number, flight_total_seats, flight_duration, flight_departure_location, flight_arrival_time, flight_arrival_location, flight_departure_time, airline_name, airline_contact_information, flight_class_id, flight_class_fare, flight_class_type) VALUES ('{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}');\n".format(
            TravEasy_strong_entities['customerId'], TravEasy_strong_entities['street'], TravEasy_strong_entities['city'], TravEasy_strong_entities['state'], TravEasy_strong_entities['zipcode'], TravEasy_strong_entities['email'], TravEasy_strong_entities['name'], TravEasy_strong_entities['restaurantId'], TravEasy_strong_entities['restaurant_name'], TravEasy_strong_entities['restaurant_location'], TravEasy_strong_entities['restaurant_price'], TravEasy_strong_entities['navigationId'], TravEasy_strong_entities['navigation_distance'], TravEasy_strong_entities['navigation_fare'], TravEasy_strong_entities['estimated_time'], TravEasy_strong_entities['transportation_method'], TravEasy_strong_entities['routing'], TravEasy_strong_entities['hotelId'], TravEasy_strong_entities['amentities'], TravEasy_strong_entities['hotel_street'], TravEasy_strong_entities['hotel_city'], TravEasy_strong_entities['hotel_state'], TravEasy_strong_entities['hotel_zipcode'], TravEasy_strong_entities['duration_of_stay'], TravEasy_strong_entities['hotel_rating'], TravEasy_strong_entities['room_type_Id'], TravEasy_strong_entities['room_type_name'], TravEasy_strong_entities['max_guest'], TravEasy_strong_entities['total_rooms'], TravEasy_strong_entities['room_type_description'], TravEasy_strong_entities['room_price'], TravEasy_strong_entities['ticketID'], TravEasy_strong_entities['flight_class'], TravEasy_strong_entities['customerName'], TravEasy_strong_entities['flight_cost'], TravEasy_strong_entities['paymentId'], TravEasy_strong_entities['payment_amount'], TravEasy_strong_entities['payment_type'], TravEasy_strong_entities['transaction_assure'], TravEasy_strong_entities['theft_prevention'], TravEasy_strong_entities['flight_number'], TravEasy_strong_entities['flight_total_seats'], TravEasy_strong_entities['flight_duration'], TravEasy_strong_entities['flight_departure_location'], TravEasy_strong_entities['flight_arrival_time'], TravEasy_strong_entities['flight_arrival_location'], TravEasy_strong_entities['flight_departure_time'], TravEasy_strong_entities['airline_name'], TravEasy_strong_entities['airline_contact_information'], TravEasy_strong_entities['flight_class_id'], TravEasy_strong_entities['flight_class_fare'], TravEasy_strong_entities['flight_class_type']))

# %% [markdown]
# ## Weak Entities

# %%
fake = Faker()

# Generate sample data for TravEasy table (weak entities)
num_customers = 60

with open('sample_data_weak_entity.sql', 'w') as f:
    for _ in range(num_customers):
        TravEasy_weak_entities = {
            'cuisineID': fake.uuid4(),
            'cuisine_description': random.choice(['Italian-inspired flavors of tomatoes, garlic, and olive oil', 'Delicate balance of Japanese seafood, rice, and traditional sauces', 
                                                  'Vibrant and spicy Mexican dishes with chili peppers and cilantro', 'Aromatic and diverse Indian spices in curries and tandoori', 
                                                  'Elegant French dishes like coq au vin and bouillabaisse', 'Bold and aromatic Thai cuisine with lemongrass and coconut milk', 
                                                  'Diverse Chinese specialties from Sichuan to Cantonese dim sum', 'Fresh Greek flavors with olive oil, herbs, and feta cheese', 
                                                  'Bold and hearty Spanish dishes like paella and tapas', 'Flavorful Brazilian dishes influenced by indigenous, African, and Portuguese cultures']),
            'cuisine_type': random.choice(['Chinese', 'American', 'Italian', 'Mediterranean', 'French', 'Mexican', 'Greek', 'Korean', 'Fusion']),
            'restaurant_booked_ID': fake.uuid4(),
            'restaurant_booked_participants': fake.random_number(digits=2),
            'restaurant_booked_datatime': fake.date_time(),
            'activitiesID': fake.uuid4(),
            'activities_name': random.choice(['skating', 'hiking', 'art gallaries', 'taste testing', 'scuba diving', 'sky diving', 'museums', 'camping', 'safari tours']),
            'activities_cost': fake.random_number(digits=3),
            'customerID': fake.uuid4(),
            'customer_demographics_type': random.choice(['Young professionals aged 25-35, urban dwellers with disposable income', 'Families with children, suburban residents seeking convenience and value',
                                                         'Retirees aged 60 and above, looking for leisurely travel experiences', 'College students and millennials, budget-conscious and tech-savvy', 
                                                         'Single adults aged 30-40, interested in fitness and wellness trends', 'Couples in their mid-40s, seeking romantic getaways and fine dining experiences', 
                                                         'Empty nesters, aged 50-65, interested in cultural and educational travel', 'Business travelers, aged 35-55, seeking comfort and efficiency', 
                                                         'Adventure seekers and thrill enthusiasts, aged 20-30, craving adrenaline-fueled experiences', 'Luxury travelers, aged 45 and above, seeking exclusive and personalized services', 
                                                         'Food enthusiasts, aged 25-45, interested in culinary experiences and gourmet dining', 'Eco-conscious travelers, aged 30-50, seeking sustainable and eco-friendly accommodations', 
                                                         'Digital nomads, aged 25-40, interested in remote work and travel experiences', 'Wellness retreat attendees, aged 35-60, seeking relaxation and rejuvenation', 
                                                         'Cultural explorers, aged 30-55, interested in history, art, and local traditions'])
        }
        f.write("INSERT INTO TravEasy_weak_entities (cuisineID, cuisine_description, cuisine_type, restaurant_booked_ID, restaurant_booked_participants, restaurant_booked_datatime, activitiesID, activities_name, activities_cost, customerID, customer_demographics_type) VALUES ('{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}', '{}');\n".format(
            TravEasy_weak_entities['cuisineID'], TravEasy_weak_entities['cuisine_description'], TravEasy_weak_entities['cuisine_type'], TravEasy_weak_entities['restaurant_booked_ID'], TravEasy_weak_entities['restaurant_booked_participants'], TravEasy_weak_entities['restaurant_booked_datatime'], TravEasy_weak_entities['activitiesID'], TravEasy_weak_entities['activities_name'], TravEasy_weak_entities['activities_cost'], TravEasy_weak_entities['customerID'], TravEasy_weak_entities['customer_demographics_type']))
